# %% [markdown]
# # ciFAIR10 Dataset

# %%
# %matplotlib inline

# %%
import sys
sys.path.append('../..')

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"         # default location for the drive

drive.mount(ROOT)              # we mount the google drive at /content/drive
# %cd ./drive/MyDrive/H2/sapienza_ml21_deic
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/H2/sapienza_ml21_deic

# %%
import numpy as np
import matplotlib.pyplot as plt

from small_data.datasets.cifair import ciFAIR10

# %%
data_root = '.'

# %% [markdown]
# ## Visualization

# %%
data = ciFAIR10(data_root, 'train')
len(data)
# Out:
# ...
#   0%|          | 0/168614301 [00:00<?, ?it/s]
# Extracting ./ciFAIR-10.zip to .
# 300

# %%
fig, axes = plt.subplots(data.num_classes, 10, figsize=(13, 1.5*data.num_classes))
for lbl, (classname, row) in enumerate(zip(data.classes, axes)):
    row[0].set_ylabel(classname)
    for img, ax in zip(data.data[data.targets == lbl], row):
        ax.imshow(img)
        ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
fig.tight_layout()
plt.show()
